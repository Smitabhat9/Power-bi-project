# %% [markdown]
# <a href="https://colab.research.google.com/github/Smitabhat9/Power-bi-project/blob/main/ADME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import pandas as pd
# !pip install numpy
import numpy as np
# !pip install matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('FinalADME..csv')
df
# Out:
#           MW  #Heavy atoms  #Aromatic heavy atoms  Fraction Csp3  \
# 0     473.44            34                     12           0.30
# 1     473.44            34                     12           0.30
# 2     473.44            34                     12           0.30
# 3     445.43            32                     12           0.32
# 4     445.43            32                     12           0.32
# ...      ...           ...                    ...            ...
# 1910  403.47            30                     12           0.40
# 1911  337.46            25                      5           0.68
# 1912  427.52            30                     12           0.36
# 1913  516.60            37                     12           0.52
# 1914  403.52            30                     15           0.40
#
#       #Rotatable bonds  #H-bond acceptors  #H-bond donors      MR    TPSA  \
# 0                   11                  8               7  126.52  219.84
# ...

# %% [markdown]
# Data preparation

# %% [markdown]
# Data separation as X and y

# %%
y= y = df['MLOGP']
y
X = df.drop('MLOGP', axis=1)
X
# Out:
#           MW  #Heavy atoms  #Aromatic heavy atoms  Fraction Csp3  \
# 0     473.44            34                     12           0.30
# 1     473.44            34                     12           0.30
# 2     473.44            34                     12           0.30
# 3     445.43            32                     12           0.32
# 4     445.43            32                     12           0.32
# ...      ...           ...                    ...            ...
# 1910  403.47            30                     12           0.40
# 1911  337.46            25                      5           0.68
# 1912  427.52            30                     12           0.36
# 1913  516.60            37                     12           0.52
# 1914  403.52            30                     15           0.40
#
#       #Rotatable bonds  #H-bond acceptors  #H-bond donors      MR    TPSA  \
# 0                   11                  8               7  126.52  219.84
# ...

# %% [markdown]
# Data splitting

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train
# Out:
#           MW  #Heavy atoms  #Aromatic heavy atoms  Fraction Csp3  \
# 983   385.44            26                      6           0.50
# 1477  429.27            23                      6           0.50
# 734   410.48            30                     11           0.39
# 843   434.46            32                     16           0.33
# 913   405.40            29                      6           0.50
# ...      ...           ...                    ...            ...
# 1879  488.77            33                     18           0.05
# 1895  359.32            24                     11           0.33
# 1859  469.56            32                     11           0.65
# 792   443.49            33                     20           0.23
# 1544  401.47            28                     17           0.29
#
#       #Rotatable bonds  #H-bond acceptors  #H-bond donors      MR    TPSA  \
# 983                  7                  6               3   99.28  133.42
# ...

# %%
X_test
# Out:
#           MW  #Heavy atoms  #Aromatic heavy atoms  Fraction Csp3  \
# 173   388.89            27                     12           0.43
# 1562  382.58            28                     10           0.56
# 1714  512.89            36                     24           0.08
# 365   458.47            34                     18           0.21
# 1378  326.32            22                     12           0.07
# ...      ...           ...                    ...            ...
# 159   421.46            31                     16           0.28
# 290   297.14            20                      5           0.50
# 656   470.60            35                     21           0.33
# 408   459.30            31                     22           0.09
# 1746  349.43            26                     17           0.20
#
#       #Rotatable bonds  #H-bond acceptors  #H-bond donors      MR    TPSA  \
# 173                  8                  5               1  109.52   62.66
# ...

# %% [markdown]
# Model Building

# %% [markdown]
# Linear Regression

# %% [markdown]
# Training the model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Applying the model to make a prediction

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)

# %%
y_lr_train_pred
# Out:
# array([0.61285508, 3.88769719, 2.2562364 , ..., 4.72778528, 2.11833312,
#        3.10513877])

# %%
y_lr_test_pred
# Out:
# array([ 2.36916013e+00,  5.37222069e+00,  3.70991753e+00,  6.10429410e-01,
#         2.16509108e+00,  3.08534634e+00,  3.67829142e+00,  2.86048440e+00,
#         8.18679934e-02,  2.20985263e+00,  4.13494639e+00,  3.36912612e-01,
#         1.85014663e+00,  1.69370834e+00,  8.82227882e-01,  1.17098331e+00,
#         9.74672403e-01,  1.59874879e+00,  2.20065568e+00,  7.38633048e-01,
#         8.34059203e-01,  3.31775224e-01,  3.35731472e+00, -7.83763396e-01,
#         4.19141623e+00,  3.16852068e+00,  2.44921568e+00,  1.63352288e+00,
#         1.57723804e+00,  1.80266877e+00,  2.95930179e+00,  2.77841025e+00,
#         3.55893877e+00,  2.68521576e+00,  1.07361132e+00, -1.40150514e-01,
#         3.12478681e+00,  4.46069703e-01,  2.69334494e+00,  2.00270473e+00,
#         2.49241195e+00,  1.67174766e+00,  3.11477499e+00,  3.46570251e+00,
#         2.08599752e+00,  1.70515116e+00, -2.92413303e-03,  3.08552428e+00,
# ...

# %% [markdown]
# Evaluate model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (Train): ', lr_train_mse)
print('LR R2 (Train): ', lr_train_r2)
print('LR MSE (Test): ', lr_test_mse)
print('LR R2 (Test): ', lr_test_r2)
# Out:
# LR MSE (Train):  0.00023851269227374245
# LR R2 (Train):  0.9999033770724988
# LR MSE (Test):  0.04298573164375429
# LR R2 (Test):  0.9824046153280662

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     0.000239    0.999903  0.042986  0.982405

# %% [markdown]
# Random Forest

# %% [markdown]
# Training the model

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# Applying the model to make a prediction

# %%
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# %% [markdown]
# Evaluate model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2  Test MSE   Test R2
# 0  Random forest     0.522719    0.788244  0.525811  0.784769

# %% [markdown]
# SVM  Regression model

# %%
# !pip install scikit-learn

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
svr = SVR() # Support Vector Machine (SVR)
# Initialize the SVR model
svr_model = SVR(kernel='rbf', C=1.0, epsilon=0.1)

# Train the model
svr_model.fit(X_train, y_train)
# Out:
# SVR()

# %%
# Make predictions
y_train_pred_svr = svr_model.predict(X_train)
y_test_pred_svr = svr_model.predict(X_test)

# Calculate performance metrics
mse_train_svr = mean_squared_error(y_train, y_train_pred_svr)
mse_test_svr = mean_squared_error(y_test, y_test_pred_svr)
rmse_train_svr = np.sqrt(mse_train_svr)
rmse_test_svr = np.sqrt(mse_test_svr)
mae_train_svr = mean_absolute_error(y_train, y_train_pred_svr)
mae_test_svr = mean_absolute_error(y_test, y_test_pred_svr)
r2_train_svr = r2_score(y_train, y_train_pred_svr)
r2_test_svr = r2_score(y_test, y_test_pred_svr)

# %%
# Print the results
print("SVM Model (SVR) Performance:")
print("Training Metrics:")
print(f"  MSE: {mse_train_svr}")
print(f"  RMSE: {rmse_train_svr}")
print(f"  MAE: {mae_train_svr}")
print(f"  R^2: {r2_train_svr}")

print("\nTesting Metrics:")
print(f"  MSE: {mse_test_svr}")
print(f"  RMSE: {rmse_test_svr}")
print(f"  MAE: {mae_test_svr}")
print(f"  R^2: {r2_test_svr}")
# Out:
# SVM Model (SVR) Performance:
# Training Metrics:
#   MSE: 1.3404845449175555
#   RMSE: 1.1577929628899786
#   MAE: 0.8862048002648312
#   R^2: 0.45696164105426273
#
# Testing Metrics:
#   MSE: 1.314379838348933
#   RMSE: 1.146464058899769
#   MAE: 0.9149900151281054
#   R^2: 0.4619838263438295

# %%
svr_results = pd.DataFrame(['Support Vector Machine', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
svr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
svr_results
# Out:
#                    Method Training MSE Training R2  Test MSE   Test R2
# 0  Support Vector Machine     0.522719    0.788244  0.525811  0.784769

# %% [markdown]
# LightGBM  Model

# %%
# !pip install lightgbm

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
igm=lgb.LGBMRegressor()
# Initialize the LightGBM Regressor
lgb_model = lgb.LGBMRegressor(n_estimators=500, random_state=42)

# Train the model
lgb_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003344 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5080
# [LightGBM] [Info] Number of data points in the train set: 1532, number of used features: 45
# [LightGBM] [Info] Start training from score 1.911495
# LGBMRegressor(n_estimators=500, random_state=42)

# %%
# Make predictions
y_train_pred_lgb = lgb_model.predict(X_train)
y_test_pred_lgb = lgb_model.predict(X_test)

# Calculate performance metrics
mse_train_lgb = mean_squared_error(y_train, y_train_pred_lgb)
mse_test_lgb = mean_squared_error(y_test, y_test_pred_lgb)
rmse_train_lgb = np.sqrt(mse_train_lgb)
rmse_test_lgb = np.sqrt(mse_test_lgb)
mae_train_lgb = mean_absolute_error(y_train, y_train_pred_lgb)
mae_test_lgb = mean_absolute_error(y_test, y_test_pred_lgb)
r2_train_lgb = r2_score(y_train, y_train_pred_lgb)
r2_test_lgb = r2_score(y_test, y_test_pred_lgb)

# %%
# Print the results
print("LightGBM Model Performance:")
print("Training Metrics:")
print(f"  MSE: {mse_train_lgb}")
print(f"  RMSE: {rmse_train_lgb}")
print(f"  MAE: {mae_train_lgb}")
print(f"  R^2: {r2_train_lgb}")

print("\nTesting Metrics:")
print(f"  MSE: {mse_test_lgb}")
print(f"  RMSE: {rmse_test_lgb}")
print(f"  MAE: {mae_test_lgb}")
print(f"  R^2: {r2_test_lgb}")
# Out:
# LightGBM Model Performance:
# Training Metrics:
#   MSE: 0.00035745427432980735
#   RMSE: 0.018906461179443584
#   MAE: 0.010189856745403309
#   R^2: 0.9998551931215722
#
# Testing Metrics:
#   MSE: 0.15804816722701556
#   RMSE: 0.3975527225752775
#   MAE: 0.2745413545564157
#   R^2: 0.9353060145142947

# %%
igb_results = pd.DataFrame(['Light Gradient Boosting machine', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
igb_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
igb_results
# Out:
#                             Method Training MSE Training R2  Test MSE  \
# 0  Light Gradient Boosting machine     0.522719    0.788244  0.525811
#
#     Test R2
# 0  0.784769

# %% [markdown]
# XGBoost model

# %%
# !pip install xgboost

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Initialize the XGBoost Regressor
xgb_model = xgb.XGBRegressor(n_estimators=500, random_state=42)

# Train the model
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Make predictions
y_train_pred_xgb = xgb_model.predict(X_train)
y_test_pred_xgb = xgb_model.predict(X_test)

# Calculate performance metrics
mse_train_xgb = mean_squared_error(y_train, y_train_pred_xgb)
mse_test_xgb = mean_squared_error(y_test, y_test_pred_xgb)
rmse_train_xgb = np.sqrt(mse_train_xgb)
rmse_test_xgb = np.sqrt(mse_test_xgb)
mae_train_xgb = mean_absolute_error(y_train, y_train_pred_xgb)
mae_test_xgb = mean_absolute_error(y_test, y_test_pred_xgb)
r2_train_xgb = r2_score(y_train, y_train_pred_xgb)
r2_test_xgb = r2_score(y_test, y_test_pred_xgb)

# %%
# Print the results
print("XGBoost Model Performance:")
print("Training Metrics:")
print(f"  MSE: {mse_train_xgb}")
print(f"  RMSE: {rmse_train_xgb}")
print(f"  MAE: {mae_train_xgb}")
print(f"  R^2: {r2_train_xgb}")

print("\nTesting Metrics:")
print(f"  MSE: {mse_test_xgb}")
print(f"  RMSE: {rmse_test_xgb}")
print(f"  MAE: {mae_test_xgb}")
print(f"  R^2: {r2_test_xgb}")
# Out:
# XGBoost Model Performance:
# Training Metrics:
#   MSE: 2.0393624220608464e-06
#   RMSE: 0.0014280624713438998
#   MAE: 0.0009007311343913265
#   R^2: 0.9999991738420058
#
# Testing Metrics:
#   MSE: 0.19801198044024368
#   RMSE: 0.444985371040716
#   MAE: 0.314730823083292
#   R^2: 0.9189475941837609

# %%
xgb_results = pd.DataFrame(['XGBoostBoosting machine', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
xgb_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
xgb_results
# Out:
#                     Method Training MSE Training R2  Test MSE   Test R2
# 0  XGBoostBoosting machine     0.522719    0.788244  0.525811  0.784769

# %% [markdown]
# Neural Network (NN) model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Define the Neural Network model
model = Sequential()

# Add layers to the model
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))  # Input layer + first hidden layer
model.add(Dense(32, activation='relu'))  # Second hidden layer
model.add(Dense(16, activation='relu'))  # Third hidden layer
model.add(Dense(1))  # Output layer (single neuron for regression)

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Make predictions
y_train_pred_nn = model.predict(X_train).flatten()
y_test_pred_nn = model.predict(X_test).flatten()
# Out:
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 14636.0205 - val_loss: 371.7220
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7005.2930 - val_loss: 46.0237
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1747.5078 - val_loss: 14.3627
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 80.8581 - val_loss: 15.2638
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 42.0438 - val_loss: 12.5256
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 36.9104 - val_loss: 13.5118
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 48.0176 - val_loss: 8.5885
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 114.2559 - val_loss: 26.3728
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 279.2819 - val_loss: 16.0046
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 139.9570 - val_loss: 9.4400
# Epoch 11/100
# ...

# %%
# Make predictions
y_train_pred_nn = model.predict(X_train).flatten()
y_test_pred_nn = model.predict(X_test).flatten()

# Calculate performance metrics
mse_train_nn = mean_squared_error(y_train, y_train_pred_nn)
mse_test_nn = mean_squared_error(y_test, y_test_pred_nn)
rmse_train_nn = np.sqrt(mse_train_nn)
rmse_test_nn = np.sqrt(mse_test_nn)
mae_train_nn = mean_absolute_error(y_train, y_train_pred_nn)
mae_test_nn = mean_absolute_error(y_test, y_test_pred_nn)
r2_train_nn = r2_score(y_train, y_train_pred_nn)
r2_test_nn = r2_score(y_test, y_test_pred_nn)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Print the results
print("Neural Network Model Performance:")
print("Training Metrics:")
print(f"  MSE: {mse_train_nn}")
print(f"  RMSE: {rmse_train_nn}")
print(f"  MAE: {mae_train_nn}")
print(f"  R^2: {r2_train_nn}")

print("\nTesting Metrics:")
print(f"  MSE: {mse_test_nn}")
print(f"  RMSE: {rmse_test_nn}")
print(f"  MAE: {mae_test_nn}")
print(f"  R^2: {r2_test_nn}")
# Out:
# Neural Network Model Performance:
# Training Metrics:
#   MSE: 5.608312755426849
#   RMSE: 2.3681876520721175
#   MAE: 0.5973852353996303
#   R^2: -1.2719612596121
#
# Testing Metrics:
#   MSE: 0.7946083528922026
#   RMSE: 0.8914080731585297
#   MAE: 0.5083504384724963
#   R^2: 0.6747423133671031

# %%
NN_results = pd.DataFrame(['Nrural Network model', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
NN_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
NN_results
# Out:
#                  Method Training MSE Training R2  Test MSE   Test R2
# 0  Nrural Network model     0.522719    0.788244  0.525811  0.784769

# %% [markdown]
# Model comparison

# %%
df_models = pd.concat([lr_results, rf_results,svr_results,igb_results,xgb_results,NN_results], axis=0)

# %%
df_models.reset_index(drop=True)
# Out:
#                             Method Training MSE Training R2  Test MSE  \
# 0                Linear regression     0.000239    0.999903  0.042986
# 1                    Random forest     0.522719    0.788244  0.525811
# 2           Support Vector Machine     0.522719    0.788244  0.525811
# 3  Light Gradient Boosting machine     0.522719    0.788244  0.525811
# 4          XGBoostBoosting machine     0.522719    0.788244  0.525811
# 5             Nrural Network model     0.522719    0.788244  0.525811
#
#     Test R2
# 0  0.982405
# 1  0.784769
# 2  0.784769
# 3  0.784769
# 4  0.784769
# 5  0.784769

# %% [markdown]
# Data visualization of prediction results

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_lr_train_pred, c="#7CAE00" ,alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict MLOGP')
plt.xlabel('Experimental MLOGP')
plt.savefig('MLOGP.png')
plt.savefig('MLOGP.pdf')
plt.show()

# %%
plt.scatter(y_test, y_lr_test_pred, label='Linear Regression', alpha=0.5)
plt.scatter(y_test, y_rf_test_pred, label='Random Forest', alpha=0.5)
plt.scatter(y_test, y_test_pred_svr, label='SVR', alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--', label='Perfect Fit')
plt.xlabel('Actual MLOGP')
plt.ylabel('Predicted MLOGP')
plt.legend()
plt.title('Actual vs Predicted MLOGP for Different Models')
plt.show()

# %%
residuals_lr = y_test - y_lr_test_pred
residuals_rf = y_test - y_rf_test_pred
residuals_svr = y_test - y_test_pred_svr

plt.figure(figsize=(10, 6))
plt.scatter(y_test, residuals_lr, label='Linear Regression', alpha=0.5)
plt.scatter(y_test, residuals_rf, label='Random Forest', alpha=0.5)
plt.scatter(y_test, residuals_svr, label='SVR', alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Actual MLOGP')
plt.ylabel('Residuals')
plt.legend()
plt.title('Residuals for Different Models')
plt.show()

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]
plt.figure(figsize=(10, 6))
plt.title('Feature Importance')
plt.bar(range(X_train.shape[1]), importances[indices], align='center')
plt.xticks(range(X_train.shape[1]), X_train.columns[indices], rotation=90)
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# Example for Random Forest
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
}

grid_search_rf = GridSearchCV(RandomForestRegressor(), param_grid, cv=5)
grid_search_rf.fit(X_train, y_train)
print("Best parameters for Random Forest:", grid_search_rf.best_params_)
# Out:
# Best parameters for Random Forest: {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 200}

# %%
from sklearn.model_selection import GridSearchCV
# Import necessary module
from sklearn.ensemble import RandomForestRegressor

# Tuning Random Forest
rf_param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5]
}

grid_search_rf = GridSearchCV(RandomForestRegressor(random_state=100), rf_param_grid, cv=5)
grid_search_rf
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=100),
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]})

# %%
# Assuming grid_search_rf from your previous cell contains the GridSearchCV object
# Fit the GridSearchCV object to the data:
grid_search_rf.fit(X_train, y_train)  # Add this line to train the model

best_rf = grid_search_rf.best_estimator_  # Extract the best model from GridSearchCV

# Now you can use best_rf for predictions

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for SVR
param_grid_svr = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto', 0.1, 1],
    'epsilon': [0.01, 0.1, 0.5]
}

# Create and train the GridSearchCV object for SVR
grid_search_svr = GridSearchCV(SVR(), param_grid_svr, cv=5)  # assuming cv=5, adjust if needed
grid_search_svr.fit(X_train, y_train)

# Get the best SVR model
best_svr = grid_search_svr.best_estimator_

# Now you can use best_svr for predictions
y_svr_train_pred = best_svr.predict(X_train)
y_svr_test_pred = best_svr.predict(X_test)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_rf_test_pred, label='Random Forest', alpha=0.5)
plt.scatter(y_test, y_svr_test_pred, label='SVR', alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--', label='Perfect Fit')
plt.xlabel('Actual MLOGP')
plt.ylabel('Predicted MLOGP')
plt.legend()
plt.title('Actual vs Predicted MLOGP after Hyperparameter Tuning')
plt.show()
